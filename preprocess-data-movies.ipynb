# %% [markdown]
# ## 1. Set Up <a class="anchor"  id="h1"></a>

# %%
import numpy as np # linear algebra
import csv
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import time
import warnings
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/tmdb-movies-daily-updates/TMDB_all_movies.csv

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)  # Add this line to suppress FutureWarnings

# %%
# Set option to display all columns
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', none)

# Set display option in pandas to show floats with thousand separators
pd.options.display.float_format = '{:,.1f}'.format

# Display multiple Variables without print() statements
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Principal dataset 900k movies from TMDB
df = pd.read_csv("/kaggle/input/tmdb-movies-daily-updates/TMDB_all_movies.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1091783 entries, 0 to 1091782
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   id                       1091783 non-null  int64
#  1   title                    1091770 non-null  object
#  2   vote_average             1091781 non-null  float64
#  3   vote_count               1091781 non-null  float64
#  4   status                   1091781 non-null  object
#  5   release_date             966507 non-null   object
#  6   revenue                  1091781 non-null  float64
#  7   runtime                  1091781 non-null  float64
#  8   budget                   1091781 non-null  float64
#  9   imdb_id                  617171 non-null   object
#  10  original_language        1091781 non-null  object
#  11  original_title           1091771 non-null  object
#  12  overview                 895324 non-null   object
#  13  popularity               1091781 non-null  float64
#  14  tagline                  165656 non-null   object
#  15  genres                   779342 non-null   object
#  16  production_companies     508087 non-null   object
#  17  production_countries     659538 non-null   object
#  18  spoken_languages         674721 non-null   object
#  19  cast                     732606 non-null   object
#  20  director                 897043 non-null   object
#  21  director_of_photography  269660 non-null   object
#  22  writers                  534745 non-null   object
#  23  producers                354083 non-null   object
#  24  music_composer           110823 non-null   object
#  25  imdb_rating              446368 non-null   float64
#  26  imdb_votes               446368 non-null   float64
#  27  poster_path              789114 non-null   object
# dtypes: float64(8), int64(1), object(19)
# memory usage: 233.2+ MB

# %% [markdown]
# ## 2. Data preprocessing <a class="anchor"  id="hdata"></a>

# %%
# Converting columns
df['revenue'] = df['revenue'].astype(float)
df['budget'] = df['budget'].astype(float)
# df['vote_count'] = df['vote_count'].fillna(0).astype(int)
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')  # errors='coerce' will convert invalid parsing to NaT
df['year'] = df['release_date'].dt.year.astype('Int64')  # Use 'Int64' to allow for NaN values

# %%
df.head(1)
df.tail(1)
# Out:
#    id  title  vote_average  vote_count    status release_date  revenue  \
# 0   2  Ariel           7.1       346.0  Released   1988-10-21      0.0
#
#    runtime  budget    imdb_id original_language original_title  \
# 0     73.0     0.0  tt0094675                fi          Ariel
#
#                                             overview  popularity tagline  \
# 0  A Finnish man goes to the city to find a job a...         1.8     NaN
#
#                           genres       production_companies  \
# 0  Comedy, Drama, Romance, Crime  Villealfa Filmproductions
#
#   production_countries spoken_languages  \
# 0              Finland            suomi
#
#                                                 cast        director  \
# 0  Merja Pulkkinen, Eetu Hilkamo, Turo Pajala, Es...  Aki Kaurismäki
#
#   director_of_photography         writers       producers music_composer  \
# 0           Timo Salminen  Aki Kaurismäki  Aki Kaurismäki            NaN
#
#    imdb_rating  imdb_votes                       poster_path  year
# 0          7.4     9,159.0  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg  1988
#               id title  vote_average  vote_count status release_date  revenue  \
# 1091782  5180730   NaN           NaN         NaN    NaN          NaT      NaN
#
#          runtime  budget imdb_id original_language original_title overview  \
# 1091782      NaN     NaN     NaN               NaN            NaN      NaN
#
#          popularity tagline genres production_companies production_countries  \
# 1091782         NaN     NaN    NaN                  NaN                  NaN
#
#         spoken_languages                                               cast  \
# 1091782              NaN  Hailee Steinfeld, Tim Martin Gleason, Holland ...
#
#               director director_of_photography  \
# 1091782  Travis Knight         Enrique Chediak
#
#                                   writers  \
# 1091782  Christina Hodson, Shoji Kawamori
#
#                                                  producers    music_composer  \
# 1091782  Chris Brigham, Stephen Davis, Don Murphy, Bria...  Dario Marianelli
#
#          imdb_rating  imdb_votes poster_path  year
# 1091782          NaN         NaN         NaN  <NA>

# %%
df['profit'] = df['revenue'] - df['budget']
df['roi'] = (df['profit'] / df['budget']) * 100

# %%
# Example to ensure 'nan' string is handled correctly
df['imdb_url'] = df['imdb_id'].apply(lambda x: f"https://www.imdb.com/title/{x}/" if pd.notnull(x) and x != 'nan' else np.nan)

# %%
df.isna().sum()
# Out:
# id                               0
# title                           13
# vote_average                     2
# vote_count                       2
# status                           2
# release_date                125276
# revenue                          2
# runtime                          2
# budget                           2
# imdb_id                     474612
# original_language                2
# original_title                  12
# overview                    196459
# popularity                       2
# tagline                     926127
# genres                      312441
# production_companies        583696
# production_countries        432245
# spoken_languages            417062
# cast                        359177
# director                    194740
# director_of_photography     822123
# writers                     557038
# producers                   737700
# music_composer              980960
# imdb_rating                 645415
# imdb_votes                  645415
# poster_path                 302669
# year                        125276
# profit                           2
# roi                        1015163
# imdb_url                    474612
# dtype: int64

# %%
df_sample = df.dropna().sample(n=1000, random_state=42)

# %%
df_sample.isna().sum()
# Out:
# id                         0
# title                      0
# vote_average               0
# vote_count                 0
# status                     0
# release_date               0
# revenue                    0
# runtime                    0
# budget                     0
# imdb_id                    0
# original_language          0
# original_title             0
# overview                   0
# popularity                 0
# tagline                    0
# genres                     0
# production_companies       0
# production_countries       0
# spoken_languages           0
# cast                       0
# director                   0
# director_of_photography    0
# writers                    0
# producers                  0
# music_composer             0
# imdb_rating                0
# imdb_votes                 0
# poster_path                0
# year                       0
# profit                     0
# roi                        0
# imdb_url                   0
# dtype: int64

# %% [markdown]
# ## 3. Extract Poster Path <a class="anchor"  id="extractposter"></a>

# %% [markdown]
# ### Set up Logger

# %%
import logging
import sys

class JupyterLoggerHandler(logging.StreamHandler):
    def __init__(self):
        super().__init__(sys.stdout)  # Use sys.stdout to force output to the notebook
    
    def emit(self, record):
        try:
            msg = self.format(record)
            stream = self.stream
            stream.write(f"{msg}\n")  # Use the notebook's standard output
            self.flush()
        except Exception:
            self.handleError(record)

# Configure logging to use the custom handler
logger = logging.getLogger()
logger.setLevel(logging.INFO)
handler = JupyterLoggerHandler()
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
# Remove all handlers that might have been added previously
while logger.handlers:
    logger.removeHandler(logger.handlers[0])
# Add the custom handler
logger.addHandler(handler)

# # Test logging
logging.info("Test logging message")
# Out:
# 2025-05-06 20:06:44,401 - INFO - Test logging message

# %%
def get_poster_paths(df):
    # Buang baris dengan nilai NaN di kolom 'poster_path'
    df = df.dropna(subset=['poster_path'])
    
    # Tambahkan kolom 'poster_url' dengan URL lengkap
    base_url = "https://www.themoviedb.org/t/p/w600_and_h900_bestv2"
    df["poster_path"] = base_url + df["poster_path"]
    
    return df

# %%
df_poster_sample = get_poster_paths(df_sample)

# %%
df_poster_sample['id'] = range(len(df_poster_sample))

# %%
import numpy as np

# Ganti nilai inf dengan NaN dulu (agar bisa diproses)
df_poster_sample[['profit', 'roi']] = df_poster_sample[['profit', 'roi']].replace([np.inf, -np.inf], np.nan)

# Ganti nilai negatif dan NaN menjadi 0
df_poster_sample['profit'] = df_poster_sample['profit'].apply(lambda x: 0 if pd.isna(x) or x < 0 else x)
df_poster_sample['roi'] = df_poster_sample['roi'].apply(lambda x: 0 if pd.isna(x) or x < 0 else x)

# %%
df_poster_sample.to_csv("testSample.csv",index=False)

# %%
# pd.set_option('display.max_colwidth', None)
pd.reset_option('display.max_colwidth')

# %%
df_poster_sample
# Out:
#          id                             title  vote_average  vote_count  \
# 453576    0                     Trauma Center           5.5       387.0
# 78646     1    Dawn of the Planet of the Apes           7.3    11,649.0
# 4855      2             Gone in Sixty Seconds           6.4     4,540.0
# 514066    3                   Malcolm & Marie           7.0     1,391.0
# 26069     4                         Norma Rae           7.2       179.0
# ...     ...                               ...           ...         ...
# 13389   995                    Come September           6.8        73.0
# 338784  996  Manikarnika: The Queen of Jhansi           6.6        51.0
# 11452   997               Ernest Goes to Camp           5.2       159.0
# 50644   998                       Unconquered           6.2        54.0
# 267226  999                             Tully           6.8     1,433.0
#
#           status release_date       revenue  runtime        budget  \
# 453576  Released   2019-12-06      92,968.0     87.0           0.0
# 78646   Released   2014-07-08 710,644,566.0    130.0 170,000,000.0
# 4855    Released   2000-06-09 237,200,000.0    118.0  90,000,000.0
# 514066  Released   2021-01-29           0.0    106.0   2,500,000.0
# 26069   Released   1979-03-02  22,228,000.0    110.0   4,500,000.0
# ...          ...          ...           ...      ...           ...
# 13389   Released   1961-01-01  14,170,000.0    112.0           0.0
# 338784  Released   2019-01-25           0.0    148.0  17,500,000.0
# 11452   Released   1987-05-22  23,509,382.0     92.0   3,000,000.0
# 50644   Released   1947-10-10           0.0    147.0   5,000,000.0
# 267226  Released   2018-05-04  15,636,462.0     96.0           0.0
#
#            imdb_id original_language                  original_title  \
# 453576   tt9625664                en                   Trauma Center
# 78646    tt2103281                en  Dawn of the Planet of the Apes
# 4855     tt0187078                en           Gone in Sixty Seconds
# 514066  tt12676326                en                 Malcolm & Marie
# 26069    tt0079638                en                       Norma Rae
# ...            ...               ...                             ...
# 13389    tt0054759                en                  Come September
# 11452     12,892.0  https://www.themoviedb.org/t/p/w600_and_h900_b...  1987
# 50644      3,113.0  https://www.themoviedb.org/t/p/w600_and_h900_b...  1947
# 267226    64,831.0  https://www.themoviedb.org/t/p/w600_and_h900_b...  2018
#
#               profit   roi                                imdb_url
# 453576      92,968.0   0.0   https://www.imdb.com/title/tt9625664/
# 78646  540,644,566.0 318.0   https://www.imdb.com/title/tt2103281/
# 4855   147,200,000.0 163.6   https://www.imdb.com/title/tt0187078/
# 514066           0.0   0.0  https://www.imdb.com/title/tt12676326/
# 26069   17,728,000.0 394.0   https://www.imdb.com/title/tt0079638/
# ...              ...   ...                                     ...
# 13389   14,170,000.0   0.0   https://www.imdb.com/title/tt0054759/
# 338784           0.0   0.0   https://www.imdb.com/title/tt6903440/
# 11452   20,509,382.0 683.6   https://www.imdb.com/title/tt0092974/
# 50644            0.0   0.0   https://www.imdb.com/title/tt0039931/
# 267226  15,636,462.0   0.0   https://www.imdb.com/title/tt5610554/
#
# [1000 rows x 32 columns]

# %% [markdown]
# #### 4. Show Posters with Details Function <a class="anchor"  id="showposter"></a>

# %%
# Show Posters Function

from IPython.display import HTML

def show_posters(df, poster_path_column='poster_path', title_column='title', date_column='release_date', 
                 overview_column='overview', director_column='director', status_column='status', 
                 genre_column='genres', output_file='posters.html'):
    html = "<div style='display: flex; flex-wrap: wrap;'>"
    for _, row in df.iterrows():
        poster_path = row[poster_path_column]
        title = row[title_column]
        release_date = row[date_column].strftime('%Y-%m-%d') if pd.notnull(row[date_column]) else 'N/A'  # Format to show only the date part
        overview = row[overview_column]
        director = row[director_column]
        status = row[status_column]
        genre = row[genre_column]
        
        if pd.notnull(poster_path):
            html += f"""
            <div style="position: relative; margin: 10px;">
                <img src="{poster_path}" alt="{title}" style="width: 200px; height: auto;"/>
                <div style="position: absolute; top: 0; left: 0; width: 200px; height: 300px; background-color: rgba(0, 0, 0, 0.7); color: white; opacity: 0; transition: opacity 0.5s;">
                    <div style="padding: 10px;">
                        <strong>{title}</strong><br>
                        Director: {director}<br>
                        Release: {release_date}<br>
                        Genre: {genre}<br>
                        <p style="font-size: 11px;">{overview}</p>
                    </div>
                </div>
            </div>
            """
        else:
            html += f"""
            <div style="position: relative; margin: 10px; width: 200px; height: 300px; background-color: rgba(0, 0, 0, 0.7); color: white;">
                <div style="padding: 10px;">
                    <strong>{title}</strong><br>
                    Director: {director}<br>
                    Release: {release_date}<br>
                    Genre: {genre}<br>
                    <p style="font-size: 11px;">{overview}</p>
                </div>
            </div>
            """
    
    html += """
    <script>
    document.querySelectorAll('div[style*="position: relative"]').forEach(function(div) {
        div.addEventListener('mouseover', function() {
            div.children[1].style.opacity = 1;
        });
        div.addEventListener('mouseout', function() {
            div.children[1].style.opacity = 0;
        });
    });
    </script>
    """
    html += "</div>"
    
    with open(output_file, 'w') as file:
        file.write(html)     
    display(HTML(html))

# %%
show_posters(df_poster_sample.sort_values(by='vote_count', ascending= False).head(20))
# Out:
# <div style='display: flex; flex-wrap: wrap;'>
#             <div style="position: relative; margin: 10px;">
#                 <img src="https://www.themoviedb.org/t/p/w600_and_h900_bestv2/jdwSkQu3XirmX18MNj8CqFWsCk.jpg" alt="Burn After Reading" style="width: 200px; height: auto;"/>
#                 <div style="position: absolute; top: 0; left: 0; width: 200px; height: 300px; background-color: rgba(0, 0, 0, 0.7); color: white; opacity: 0; transition: opacity 0.5s;">
#                     <div style="padding: 10px;">
#                         <strong>Burn After Reading</strong><br>
#                         Director: Ethan Coen, Joel Coen<br>
#                         Release: 2008-09-05<br>
#                         Genre: Comedy, Drama<br>
#                         <p style="font-size: 11px;">When a disc containing memoirs of a former CIA analyst falls into the hands of gym employees, Linda and Chad, they see a chance to make enough money for Linda to have life-changing cosmetic surgery. Predictably, events whirl out of control for the duo, and those in their orbit.</p>
#                     </div>
#                 </div>
#             </div>
#
#             <div style="position: relative; margin: 10px;">
#                 <img src="https://www.themoviedb.org/t/p/w600_and_h900_bestv2/ckmYng37zey8INYf6d10cVgIG93.jpg" alt="The Sting" style="width: 200px; height: auto;"/>
#                 <div style="position: absolute; top: 0; left: 0; width: 200px; height: 300px; background-color: rgba(0, 0, 0, 0.7); color: white; opacity: 0; transition: opacity 0.5s;">
#                     <div style="padding: 10px;">
#                         <strong>The Sting</strong><br>
#                         Director: George Roy Hill<br>
#                         Release: 1973-12-25<br>
#                         Genre: Comedy, Crime, Drama<br>
#                         <p style="font-size: 11px;">A novice con man teams up with an acknowledged master to avenge the murder of a mutual friend by pulling off the ultimate big con and swindling a fortune from a big-time mobster.</p>
#                     </div>
#                 </div>
#             </div>
#
#             <div style="position: relative; margin: 10px;">
#                 <img src="https://www.themoviedb.org/t/p/w600_and_h900_bestv2/4fVMognsmbogzkfY7DY0Bvn7h7Y.jpg" alt="Army of Thieves" style="width: 200px; height: auto;"/>
#                 <div style="position: absolute; top: 0; left: 0; width: 200px; height: 300px; background-color: rgba(0, 0, 0, 0.7); color: white; opacity: 0; transition: opacity 0.5s;">
#                     <div style="padding: 10px;">
#                         <strong>Army of Thieves</strong><br>
#                         Director: Matthias Schweighöfer<br>
#                         Release: 2021-10-29<br>
#                         Genre: Action, Crime, Comedy<br>
#                         <p style="font-size: 11px;">A mysterious woman recruits bank teller Ludwig Dieter to lead a group of aspiring thieves on a top-secret heist during the early stages of the zombie apocalypse.</p>
#                     </div>
#                 </div>
#             </div>
#
#             <div style="position: relative; margin: 10px;">
#                 <img src="https://www.themoviedb.org/t/p/w600_and_h900_bestv2/9hBpFyJ3pGdupXbaC2L7nGvLMBn.jpg" alt="Greta" style="width: 200px; height: auto;"/>
#                 <div style="position: absolute; top: 0; left: 0; width: 200px; height: 300px; background-color: rgba(0, 0, 0, 0.7); color: white; opacity: 0; transition: opacity 0.5s;">
#                     <div style="padding: 10px;">
#                         <strong>Greta</strong><br>
#                         Director: Neil Jordan<br>
#                         Release: 2019-02-28<br>
#                         Genre: Mystery, Thriller, Horror, Drama<br>
#                         <p style="font-size: 11px;">A young woman returns a lonely widow’s lost purse, leading to an unlikely relationship between the two — until the young woman discovers the widow might not be all that she seems.</p>
#                     </div>
#                 </div>
#             </div>
#
#             <div style="position: relative; margin: 10px;">
#                 <img src="https://www.themoviedb.org/t/p/w600_and_h900_bestv2/fYtHxTxlhzD4QWfEbrC1rypysSD.jpg" alt="Gabriel's Inferno: Part III" style="width: 200px; height: auto;"/>
#                 <div style="position: absolute; top: 0; left: 0; width: 200px; height: 300px; background-color: rgba(0, 0, 0, 0.7); color: white; opacity: 0; transition: opacity 0.5s;">
#                     <div style="padding: 10px;">
#                         <strong>Gabriel's Inferno: Part III</strong><br>
#                         Director: Tosca Musk<br>
#                         Release: 2020-11-19<br>
#                         Genre: Romance, Drama<br>
#                         <p style="font-size: 11px;">The final part of the film adaption of the erotic romance novel Gabriel's Inferno written by an anonymous Canadian author under the pen name Sylvain Reynard.</p>
#                     </div>
#                 </div>
#             </div>
#
#             <div style="position: relative; margin: 10px;">
#                 <img src="https://www.themoviedb.org/t/p/w600_and_h900_bestv2/ecyPkx1kI3OtRrU5QhddPfgv2mx.jpg" alt="The Seven Year Itch" style="width: 200px; height: auto;"/>
#                 <div style="position: absolute; top: 0; left: 0; width: 200px; height: 300px; background-color: rgba(0, 0, 0, 0.7); color: white; opacity: 0; transition: opacity 0.5s;">
#                     <div style="padding: 10px;">
#                         <strong>The Seven Year Itch</strong><br>
#                         Director: Billy Wilder<br>
#                         Release: 1955-06-03<br>
#                         Genre: Comedy, Romance<br>
#                         <p style="font-size: 11px;">With his family away for their annual summer holiday, a publishing executive decides to live a bachelor's life. The beautiful but ditzy blonde from the apartment above catches his eye and they soon start spending time together—maybe a little too much time!</p>
#                     </div>
#                 </div>
#             </div>
#
#             <div style="position: relative; margin: 10px;">
#                 <img src="https://www.themoviedb.org/t/p/w600_and_h900_bestv2/dDF11WTsDVY1i25VNPbwBjPk6t1.jpg" alt="Frequencies" style="width: 200px; height: auto;"/>
#                 <div style="position: absolute; top: 0; left: 0; width: 200px; height: 300px; background-color: rgba(0, 0, 0, 0.7); color: white; opacity: 0; transition: opacity 0.5s;">
#                     <div style="padding: 10px;">
#                         <strong>Frequencies</strong><br>
#                         Director: Darren Paul Fisher<br>
#                         Release: 2013-07-24<br>
#                         Genre: Romance, Science Fiction, Mystery<br>
#                         <p style="font-size: 11px;">The story of the forbidden relationship between a 'low born' boy and a 'high born' girl in an alternate reality where every person's relationships and life worth are determined by their innate 'frequencies'.</p>
#                     </div>
#                 </div>
#             </div>
#
#             <div style="position: relative; margin: 10px;">
#                 <img src="https://www.themoviedb.org/t/p/w600_and_h900_bestv2/5PqKsWVlyIFuMeV1UkK6Q9Q8y9k.jpg" alt="Fort Apache" style="width: 200px; height: auto;"/>
#                 <div style="position: absolute; top: 0; left: 0; width: 200px; height: 300px; background-color: rgba(0, 0, 0, 0.7); color: white; opacity: 0; transition: opacity 0.5s;">
#                     <div style="padding: 10px;">
#                         <strong>Fort Apache</strong><br>
#                         Director: John Ford<br>
#                         Release: 1948-05-21<br>
#                         Genre: Western<br>
#                         <p style="font-size: 11px;">Owen Thursday sees his new posting to the desolate F
